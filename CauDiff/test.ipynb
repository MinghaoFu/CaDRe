# %%
import numpy as np
import matplotlib.pyplot as plt

time_index = 1000
# Define the size of the matrix
n = 5  # You can change this to any desired size

# Create an n x n matrix with random values
matrix = np.array([[0.24, 0.73], [0.01, 0.31]])

# Plot the heatmap
plt.imshow(matrix, cmap='coolwarm', interpolation='nearest', vmin=-1, vmax=1)
plt.colorbar()
plt.title(f'{n} x {n} estimated B in time-step {time_index}')
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.show()

matrix = np.array([[0, 1.2], [0, 0]])

# Plot the heatmap
plt.imshow(matrix, cmap='coolwarm', interpolation='nearest', vmin=-1, vmax=1)
plt.colorbar()
plt.title(f'{n} x {n} B gt in time-step {time_index}')
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.show()

# %%
time_index = 1000
# Define the size of the matrix
n = 3  # You can change this to any desired size

# Create an n x n matrix with random values
matrix = np.array([[0, 0, 0.53], [1, 0, 0], [0, 0, -0]])

# Plot the heatmap
plt.imshow(matrix, cmap='coolwarm', interpolation='nearest', vmin=-1, vmax=1)
plt.colorbar()
plt.title(f'{n} x {n} estimated B in time-step {time_index}')
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.show()

matrix = np.array([[-0.5759,  0.1293, -0.31705],
        [-0.38225, -0.0437,  0.2299],
        [ 0.0250,  0.05331,  1.1590]])

# Plot the heatmap
plt.imshow(matrix, cmap='coolwarm', interpolation='nearest', vmin=-1, vmax=1)
plt.colorbar()
plt.title(f'{n} x {n} B gt in time-step {time_index}')
plt.xlabel('Columns')
plt.ylabel('Rows')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the data
bt = np.load('/fsx/homes/Minghao.Fu@mbzuai.ac.ae/workspace/climate-project/General/data/nonparametric_bt/bt.npy')
npz = np.load('/fsx/homes/Minghao.Fu@mbzuai.ac.ae/workspace/climate-project/General/data/nonparametric_bt/data.npz')
zt = npz['zt'].reshape(160000, 3, 2)
bt = bt.reshape(160000, 3, 2).mean(axis=-1)

# Create a figure
plt.figure(figsize=(10, 8))

# Plot histograms for all three columns in the same graph
plt.hist(bt[:, 0], bins=50, alpha=0.5, color='blue', label='bt[:, 0]')
plt.hist(bt[:, 1], bins=50, alpha=0.5, color='green', label='bt[:, 1]')
plt.hist(bt[:, 2], bins=50, alpha=0.5, color='red', label='bt[:, 2]')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Distribution of bt Columns')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the data
npz = np.load('/fsx/homes/Minghao.Fu@mbzuai.ac.ae/workspace/climate-project/General/data/nonparametric_bt/data.npz')
zt = npz['zt']

# Reshape and process zt
zt = zt.reshape(160000, 3, 2)

# Create a figure
plt.figure(figsize=(10, 8))

# Plot for the first type of zt
plt.scatter(zt[:, 0, 0], zt[:, 0, 1], alpha=0.5, color='blue', label='zt-1')

# Plot for the second type of zt
plt.scatter(zt[:, 1, 0], zt[:, 1, 1], alpha=0.5, color='green', label='zt')

# Plot for the third type of zt
plt.scatter(zt[:, 2, 0], zt[:, 2, 1], alpha=0.5, color='red', label='zt+1')

# Add labels and title
plt.xlabel('Coordinate X')
plt.ylabel('Coordinate Y')
plt.title('Scatter Plot of Different Types of zt')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
